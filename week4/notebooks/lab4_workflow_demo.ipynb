# %% [markdown]
# # Лабораторная работа №4
# ## Workflow Automation — Автоматизация рабочих процессов с AI
#
# **Автор:** [ФИО]
# **Группа:** [НОМЕР ГРУППЫ]

# %%
import sys
sys.path.append('..')

from src.webhook_handler import WorkflowClient
from src.api_client import YandexGPTClient

# %% [markdown]
# ## 1. Инициализация клиентов

# %%
workflow_client = WorkflowClient()
gpt_client = YandexGPTClient()

print('Клиенты инициализированы')

# %% [markdown]
# ## 2. Проверка доступности n8n

# %%
status = workflow_client.check_workflow_status()
print(f"n8n статус: {status}")

# %% [markdown]
# ## 3. Тестирование классификации текста

# %%
result = gpt_client.classify_text("Не работает вход в систему, ошибка 403")
print(f"Классификация: {result}")

# %% [markdown]
# ## 4. Отправка заявки через webhook

# %%
result = workflow_client.send_application(
    message="Не работает вход в систему, ошибка 403",
    contact="user@example.com",
    priority="high"
)
print(f"Результат: {result}")

# %% [markdown]
# ## 5. Тестирование инцидента безопасности

# %%
security_result = gpt_client.analyze_security_incident(
    "Multiple failed login attempts from 192.168.1.100"
)
print(f"Анализ инцидента: {security_result}")

# %% [markdown]
# ## Выводы
#
# [Напишите выводы по результатам выполнения лабораторной работы]
